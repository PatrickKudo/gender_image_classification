# %% [markdown]
# # Densenet201 Model 3a
# ## Preprocessing method: ImageDataGenerator()
# ## Image size: (224, 224)
# ## Images: Grayscale
# ## Frozen pretrained layers
# ## Image transformation

# %%
import pandas as pd
import numpy as np
import io
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
from keras import backend as K
K.clear_session()

# %%
path_training = 'gender_images/Training/'
path_validation = 'gender_images/Validation/'

# %%
image_size = (224, 224)
batch_size = 64

datagen_transform = ImageDataGenerator(
    rescale =1./255,
    validation_split=.2,
    rotation_range=20,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=.2,
    zoom_range=.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

datagen_val = ImageDataGenerator(
    rescale = 1./255,
)

train_ds = datagen_transform.flow_from_directory(
    path_training,
    seed=1993,
    target_size=image_size,
    batch_size=batch_size,
    classes=['female','male'],
    shuffle=True,
    color_mode="grayscale"
)

val_ds = datagen_transform.flow_from_directory(
    path_validation,
    seed=1993,
    target_size=image_size,
    batch_size=batch_size,
    classes=['female','male'],
    shuffle=True,
    color_mode="grayscale"
)
# Out:
# Found 47009 images belonging to 2 classes.
# Found 11649 images belonging to 2 classes.

# %%
DN201_model = keras.applications.DenseNet201(weights='imagenet', include_top=True)
DN201_model.trainable = False

# Model layers
input_tensor = tf.keras.layers.Input(shape=(224, 224, 1))
x = keras.layers.Conv2D(3,(3,3),padding='same')(input_tensor)
x = DN201_model(x)
out = keras.layers.Dense(2, activation='softmax')(x)

# Set early stopping after certain number of epochs
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
epochs=1000     # Set epochs

# Generate model
model = keras.Model(inputs = input_tensor, outputs = out)
model.compile(optimizer=keras.optimizers.Adam(1e-2),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 3)       30
#
#  densenet201 (Functional)    (None, 1000)              20242984
#
#  dense (Dense)               (None, 2)                 2002
#
# =================================================================
# Total params: 20,245,016
# Trainable params: 2,032
# Non-trainable params: 20,242,984
# _________________________________________________________________

# %%
mod_fit = model.fit(train_ds, 
                      epochs=epochs, 
                      validation_data=val_ds,
                      callbacks=[callback])
# Out:
# Epoch 1/1000
# 735/735 [==============================] - 214s 278ms/step - loss: 0.5477 - accuracy: 0.7592 - val_loss: 0.4863 - val_accuracy: 0.7812
# Epoch 2/1000
# 735/735 [==============================] - 206s 280ms/step - loss: 0.4770 - accuracy: 0.7838 - val_loss: 0.4573 - val_accuracy: 0.7972
# Epoch 3/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4647 - accuracy: 0.7927 - val_loss: 0.4509 - val_accuracy: 0.8028
# Epoch 4/1000
# 735/735 [==============================] - 200s 272ms/step - loss: 0.4619 - accuracy: 0.7922 - val_loss: 0.4417 - val_accuracy: 0.8061
# Epoch 5/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4510 - accuracy: 0.7976 - val_loss: 0.4451 - val_accuracy: 0.8076
# Epoch 6/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4488 - accuracy: 0.8004 - val_loss: 0.4307 - val_accuracy: 0.8103
# Epoch 7/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4440 - accuracy: 0.8031 - val_loss: 0.4373 - val_accuracy: 0.8118
# Epoch 8/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4413 - accuracy: 0.8055 - val_loss: 0.4242 - val_accuracy: 0.8135
# Epoch 9/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4373 - accuracy: 0.8082 - val_loss: 0.4215 - val_accuracy: 0.8165
# Epoch 10/1000
# 735/735 [==============================] - 200s 272ms/step - loss: 0.4364 - accuracy: 0.8101 - val_loss: 0.4207 - val_accuracy: 0.8190
# Epoch 11/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4362 - accuracy: 0.8078 - val_loss: 0.4234 - val_accuracy: 0.8204
# Epoch 12/1000
# 735/735 [==============================] - 199s 270ms/step - loss: 0.4339 - accuracy: 0.8131 - val_loss: 0.4209 - val_accuracy: 0.8227
# Epoch 13/1000
# 735/735 [==============================] - 199s 270ms/step - loss: 0.4285 - accuracy: 0.8130 - val_loss: 0.4071 - val_accuracy: 0.8214
# Epoch 14/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4292 - accuracy: 0.8132 - val_loss: 0.4226 - val_accuracy: 0.8170
# Epoch 15/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4285 - accuracy: 0.8135 - val_loss: 0.4128 - val_accuracy: 0.8207
# Epoch 16/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4271 - accuracy: 0.8168 - val_loss: 0.4093 - val_accuracy: 0.8247
# Epoch 17/1000
# 735/735 [==============================] - 200s 271ms/step - loss: 0.4246 - accuracy: 0.8158 - val_loss: 0.4154 - val_accuracy: 0.8226
# Epoch 18/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4241 - accuracy: 0.8185 - val_loss: 0.4144 - val_accuracy: 0.8221
# Epoch 19/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4252 - accuracy: 0.8149 - val_loss: 0.4076 - val_accuracy: 0.8287
# Epoch 20/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4210 - accuracy: 0.8195 - val_loss: 0.4079 - val_accuracy: 0.8284
# Epoch 21/1000
# 735/735 [==============================] - 200s 272ms/step - loss: 0.4228 - accuracy: 0.8174 - val_loss: 0.4122 - val_accuracy: 0.8239
# Epoch 22/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4222 - accuracy: 0.8183 - val_loss: 0.4127 - val_accuracy: 0.8263
# Epoch 23/1000
# 735/735 [==============================] - 199s 271ms/step - loss: 0.4214 - accuracy: 0.8179 - val_loss: 0.4045 - val_accuracy: 0.8226

# %%
acc= mod_fit.history['accuracy']
val_acc = mod_fit.history['val_accuracy']

loss = mod_fit.history['loss']
val_loss = mod_fit.history['val_loss']

epochs_range = range(0, 23)

plt.figure(figsize=(8, 10))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
print(str('Top Training Accuracy: ') + str(round(max(acc),4)))
print(str('Top Validation Accuracy: ') + str(round(max(val_acc),4)))
# Out:
# Top Training Accuracy: 0.8195
# Top Validation Accuracy: 0.8287

# %%
model.save('GC weights/Frozen/mod3a-gs/mod3a_gs_frozen.h5')
